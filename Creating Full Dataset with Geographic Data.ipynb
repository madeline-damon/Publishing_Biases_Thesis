# %% [markdown]
# # Purpose 1: Combine Data
#
# Currently, I have one Excel workbook with various sheets of Web of Science records. The code below easily combines all sheets into one sheet for ease of use.

# %%
import pandas as pd
import xlrd

# %%
df = pd.concat(pd.read_excel('Full_WoS_Sample.xlsx',sheet_name=None), ignore_index=True)

# %%
df
# Out:
#       Publication Type                                            Authors  \
# 0                    J  Glidden, CK; Field, LC; Bachhuber, S; Hennesse...
# 1                    J        Avery-Gomm, S; Borrelle, SB; Provencher, JF
# 2                    J                                         Guerra, AS
# 3                    J  Halliday, WD; Dawson, J; Yurkowski, DJ; Doniol...
# 4                    J  Samhouri, JF; Feist, BE; Fisher, MC; Liu, O; W...
# ...                ...                                                ...
# 49995                J  Wang, RL; Jiang, CX; Huang, TT; Zhang, Z; Wang...
# 49996                J  Shapouri, MRSA; Mahmoodi, P; Najafabadi, MG; H...
# 49997                J  Brown, G; Rhodes, J; Lunney, D; Goldingay, R; ...
# 49998                J                   Castro, KC; Leblond, M; Cote, SD
# 49999                J  Idan, T; Goren, L; Shefer, S; Brickner, I; Ila...
#
#       Book Authors Book Editors Book Group Authors  \
# 0              NaN          NaN                NaN
# 1              NaN          NaN                NaN
# 2              NaN          NaN                NaN
# 3              NaN          NaN                NaN
# 4              NaN          NaN                NaN
# ...            ...          ...                ...
# 49995          NaN          NaN                NaN
# 49996          NaN          NaN                NaN
# 49997          NaN          NaN                NaN
# 49998          NaN          NaN                NaN
# 49999          NaN          NaN                NaN
#
#                                        Author Full Names  \
# 0      Glidden, Caroline K.; Field, Laurel C.; Bachhu...
# 1      Avery-Gomm, Stephanie; Borrelle, Stephanie B.;...
# 2                                      Guerra, Ana Sofia
# 3      Halliday, William D.; Dawson, Jackie; Yurkowsk...
# 4      Samhouri, Jameal F.; Feist, Blake E.; Fisher, ...
# ...                                                  ...
# 49995  Wang, Rulin; Jiang, Chunxian; Huang, Tingting;...
# 49996  Shapouri, Masoud Reza Seyfi Abad; Mahmoodi, Pe...
# 49997  Brown, Greg; Rhodes, Jonathan; Lunney, Daniel;...
# 49998  Castro, Karina Charest; Leblond, Mathieu; Cote...
# 49999  Idan, Tal; Goren, Liron; Shefer, Sigal; Brickn...
#
#       Book Author Full Names Group Authors  \
# 0                        NaN           NaN
# 1                        NaN           NaN
# 2                        NaN           NaN
# 3                        NaN           NaN
# 4                        NaN           NaN
# ...                      ...           ...
# 49995                    NaN           NaN
# 49996                    NaN           NaN
# 49997                    NaN           NaN
# 49998                    NaN           NaN
# 49999                    NaN           NaN
#
#                                            Article Title  \
# 0                 Strategies for managing marine disease
# 1      Linking plastic ingestion research with marine...
# 2      Wolves of the Sea: Managing human-wildlife con...
# 3      Vessel risks to marine wildlife in the Talluru...
# 4      Marine heatwave challenges solutions to human-...
# ...                                                  ...
# 49995  A Simulation Study of the Geographical Distrib...
# 49996  A novel competitive ELISA for detection of ant...
# 49997  The influence of sampling design on spatial da...
# 49998  Costs and benefits of post-weaning association...
# 49999  Does Depth Matter? Reproduction Pattern Plasti...
#
#                                             Source Title  ...  \
# 0                                ECOLOGICAL APPLICATIONS  ...
# 1                       SCIENCE OF THE TOTAL ENVIRONMENT  ...
# 2                                          MARINE POLICY  ...
# 3                         ENVIRONMENTAL SCIENCE & POLICY  ...
# 4      PROCEEDINGS OF THE ROYAL SOCIETY B-BIOLOGICAL ...  ...
# ...                                                  ...  ...
# 49995            POLISH JOURNAL OF ENVIRONMENTAL STUDIES  ...
# 49996                          VETERINARY RESEARCH FORUM  ...
# 49997                                TRANSACTIONS IN GIS  ...
# 49998                                          BEHAVIOUR  ...
# 49999                        FRONTIERS IN MARINE SCIENCE  ...
#
#       Web of Science Index  Research Areas  IDS Number Pubmed Id  \
# 0                      NaN             NaN         NaN       NaN
# 1                      NaN             NaN         NaN       NaN
# 2                      NaN             NaN         NaN       NaN
# 3                      NaN             NaN         NaN       NaN
# 4                      NaN             NaN         NaN       NaN
# ...                    ...             ...         ...       ...
# 49995                  NaN             NaN         NaN       NaN
# 49996                  NaN             NaN         NaN       NaN
# 49997                  NaN             NaN         NaN       NaN
# 49998                  NaN             NaN         NaN       NaN
# 49999                  NaN             NaN         NaN       NaN
#
#        Open Access Designations  Highly Cited Status  Hot Paper Status  \
# 0       Green Submitted, hybrid                  NaN               NaN
# 1               Green Submitted                  NaN               NaN
# 2                           NaN                  NaN               NaN
# 3       Green Published, hybrid                  NaN               NaN
# 4       Green Published, hybrid                  NaN               NaN
# ...                         ...                  ...               ...
# 49995                      gold                  NaN               NaN
# 49996                       NaN                  NaN               NaN
# 49997                       NaN                  NaN               NaN
# 49998                       NaN                  NaN               NaN
# 49999                      gold                  NaN               NaN
#
#        Date of Export   UT (Unique WOS ID)               Web of Science Record
# 0                 NaN  WOS:000828498100001  View Full Record in Web of Science
# 1                 NaN  WOS:000436605400143  View Full Record in Web of Science
# 2                 NaN  WOS:000454467200045  View Full Record in Web of Science
# 3                 NaN  WOS:000723249900001  View Full Record in Web of Science
# 4                 NaN  WOS:000724057500007  View Full Record in Web of Science
# ...               ...                  ...                                 ...
# 49995             NaN  WOS:000513486600034  View Full Record in Web of Science
# 49996             NaN  WOS:000880674100014  View Full Record in Web of Science
# 49997             NaN  WOS:000477297000001  View Full Record in Web of Science
# 49998             NaN  WOS:000430341100004  View Full Record in Web of Science
# 49999             NaN  WOS:000601400400001  View Full Record in Web of Science
#
# [50000 rows x 72 columns]

# %% [markdown]
# This seems to have worked, so now I'll save to a csv file

# %%
df.to_csv('Combined_WoS_Dataset.csv')

# %% [markdown]
# # Purpose 2: Prepare Data For Sampling
#
# Sampling will involve dividing articles by where the first author resided at the time of publication into US and non-US groups. This involves using regex code to pull just the first author's address out of the address data provided for all authors by WoS.

# %%
address_list=list(df['Addresses'])
address_list[:3]

# %%
address_strings=[]

for item in address_list:  #Make everything in the column  a string of text
    string=str(item)
    address_strings.append(string)

# %% [markdown]
# ## Using pycountry to create a list of expected countries

# %%
import pycountry

# %%
countries=[]
for string in address_strings:
    for country in pycountry.countries:
        if country.name in string:  ##Country name in pycountry is United States, not USA like Web of Science uses
            countries.append(country.name)

# %%
unique_countries=set(countries) ##Removes duplicates
print(len(unique_countries))
# Out:
# 189

# %% [markdown]
# ## Regex Method for Gathering First Author Address Data

# %%
import re

# %%
country_regex=r'[a-zA-Z ]+;|[a-zA-Z ]+$'

# %%
#finding regex matches
match_list=list()

for address in address_strings:
    match=re.findall(country_regex,address)
    match_list.append(match)

#Cleaning the list of regex matches
list_of_matches=list()

for matches in match_list:
    in_list=matches
    out_list= [re.sub(';', '', item) for item in in_list]
    
    list_of_matches.append(out_list)

# %%
#Checking to see if length of records is still correct
len(list_of_matches)
# Out:
# 50000

# %%
list_of_matches[1]
# Out:
# [' Australia', ' Australia', ' New Zealand', ' Canada']

# %%
#Remove leading spaces
##Fixing spaces on all entries
clean_countries=[[country.lstrip() for country in matches] for matches in list_of_matches]
len(clean_countries) #length is correct
# Out:
# 50000

# %%
clean_countries[100:110]
# Out:
# [['Spain', 'Spain', 'Arthur', 'Portugal', 'Kenya', 'Australia', 'Norway'],
#  ['Canada', 'Canada', 'Canada'],
#  ['Antonio', 'England'],
#  ['Georgia', 'Greece'],
#  ['USA', 'USA'],
#  ['Daniel',
#   'Gustav',
#   'Marcus',
#   'Sweden',
#   'Giovanni',
#   'Hung',
#   'Australia',
#   'USA',
#   'Czech Republic',
#   'Sweden',
#   'England',
#   'Marcus',
#   'USA',
#   'Australia',
#   'Australia',
#   'Italy',
#   'Australia',
#   'England'],
#  ['Kenya', 'Norway', 'Germany', 'Kenya'],
#  ['Alemayehu', 'Ethiopia', 'England'],
#  ['South Africa', 'South Africa', 'South Africa'],
#  ['Adolfo', 'Spain', 'Adolfo', 'Samir', 'Cape Verde', 'Cape Verde', 'Wales']]

# %%
#Just based on the regex, sometimes names are grabbed in addition to country of residence

##Next I need to get rid of the names still present and collect just the first author's country
    
first_author_country=list()
for address in clean_countries:
    
    if len(address)==1:
        first_author_country.append(address[0])
        
       
    else: 
        found_country = False
        for idx,potential_country in enumerate(address):
            if potential_country in unique_countries:
                first_author_country.append(potential_country)
                found_country= True
                
                break
                
        #This code handles countries that appeared in WoS data that weren't in pycountries
        
        #Current code appends just 'USA' because all missing countries have been corrected
        #The only error left is when there is a state abbreiviation in front of USA in an address
        if not found_country :
            first_author_country.append('USA')
#             first_author_country.append('Country not found')
#             print('Didnt find country in '+str(address))

# %%
#Here are some countries that weren't included in pycountry, but are in the WoS data
#This was found thorugh the 'Didn't find country in...' command
countries_to_add=['England','Taiwan','Scotland','Iran','Peoples R China','USA','Czech Republic','North Ireland','South Korea',
'Vietnam','Russia','Tanzania','U Arab Emirates','Wales','Rep Congo','Bolivia','DEM REP CONGO','Trinidad Tobago',
 'Papua N Guinea','Venezuela']

for country in countries_to_add:
    unique_countries.add(country)

# %%
len(first_author_country)
# Out:
# 50000

# %%
first_author_country[:10]
# Out:
# ['USA',
#  'Australia',
#  'USA',
#  'Canada',
#  'USA',
#  'Scotland',
#  'USA',
#  'Kenya',
#  'USA',
#  'India']

# %% [markdown]
# # Inputing geographic data back into dataset

# %%
df=pd.read_csv('Combined_WoS_Dataset.csv')
# Out:
# C:\Users\12622\AppData\Local\Temp\ipykernel_15144\4258133060.py:1: DtypeWarning: Columns (11,12,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Combined_WoS_Dataset.csv')

# %%
df
# Out:
#                                                  Authors  \
# 0      Glidden, CK; Field, LC; Bachhuber, S; Hennesse...
# 1            Avery-Gomm, S; Borrelle, SB; Provencher, JF
# 2                                             Guerra, AS
# 3      Halliday, WD; Dawson, J; Yurkowski, DJ; Doniol...
# 4      Samhouri, JF; Feist, BE; Fisher, MC; Liu, O; W...
# ...                                                  ...
# 49995  Wang, RL; Jiang, CX; Huang, TT; Zhang, Z; Wang...
# 49996  Shapouri, MRSA; Mahmoodi, P; Najafabadi, MG; H...
# 49997  Brown, G; Rhodes, J; Lunney, D; Goldingay, R; ...
# 49998                   Castro, KC; Leblond, M; Cote, SD
# 49999  Idan, T; Goren, L; Shefer, S; Brickner, I; Ila...
#
#                                        Author Full Names  \
# 0      Glidden, Caroline K.; Field, Laurel C.; Bachhu...
# 1      Avery-Gomm, Stephanie; Borrelle, Stephanie B.;...
# 2                                      Guerra, Ana Sofia
# 3      Halliday, William D.; Dawson, Jackie; Yurkowsk...
# 4      Samhouri, Jameal F.; Feist, Blake E.; Fisher, ...
# ...                                                  ...
# 49995  Wang, Rulin; Jiang, Chunxian; Huang, Tingting;...
# 49996  Shapouri, Masoud Reza Seyfi Abad; Mahmoodi, Pe...
# 49997  Brown, Greg; Rhodes, Jonathan; Lunney, Daniel;...
# 49998  Castro, Karina Charest; Leblond, Mathieu; Cote...
# 49999  Idan, Tal; Goren, Liron; Shefer, Sigal; Brickn...
#
#                                            Article Title  \
# 0                 Strategies for managing marine disease
# 1      Linking plastic ingestion research with marine...
# 2      Wolves of the Sea: Managing human-wildlife con...
# 3      Vessel risks to marine wildlife in the Talluru...
# 4      Marine heatwave challenges solutions to human-...
# ...                                                  ...
# 49995  A Simulation Study of the Geographical Distrib...
# 49996  A novel competitive ELISA for detection of ant...
# 49997  The influence of sampling design on spatial da...
# 49998  Costs and benefits of post-weaning association...
# 49999  Does Depth Matter? Reproduction Pattern Plasti...
#
#                                             Source Title  \
# 0                                ECOLOGICAL APPLICATIONS
# 1                       SCIENCE OF THE TOTAL ENVIRONMENT
# 2                                          MARINE POLICY
# 3                         ENVIRONMENTAL SCIENCE & POLICY
# 4      PROCEEDINGS OF THE ROYAL SOCIETY B-BIOLOGICAL ...
# ...                                                  ...
# 49995            POLISH JOURNAL OF ENVIRONMENTAL STUDIES
# 49996                          VETERINARY RESEARCH FORUM
# 49997                                TRANSACTIONS IN GIS
# 49998                                          BEHAVIOUR
# 49999                        FRONTIERS IN MARINE SCIENCE
#
#                                          Author Keywords  \
# 0      disease ecology; marine conservation; marine w...
# 1      Plastic pollution; Conservation; Policy; Waste...
# 2      Competition; Depredation; Human-wildlife confl...
# 3      Arctic; Climate change; Marine mammals; Seabir...
# 4      trade-offs; dynamic ocean management; Dungenes...
# ...                                                  ...
# 49995  Actinidia arguta; MaxEnt; environmental factor...
# 49996  Bovine viral diarrhea; Competitive ELISA; Nons...
# 49997                                                NaN
# 49998  energy allocation trade-off; kinship interacti...
# 49999  Chondrosia reniformis; Axinella polypoides; oo...
#
#                                            Keywords Plus  \
# 0      ACUTE RESPIRATORY SYNDROME; ENDANGERED WHITE A...
# 1      DEBRIS; MANAGEMENT; SEABIRDS; MICROPLASTICS; S...
# 2      CONSERVATION; MARINE; DEPREDATION; FISHERIES; ...
# 3      CLIMATE-CHANGE; BEAUFORT SEA; SEABIRDS; SHIPS;...
# 4      ECOSYSTEM SERVICES; DYNAMIC OCEAN; WEST-COAST;...
# ...                                                  ...
# 49995  CLIMATE-CHANGE; POTENTIAL DISTRIBUTION; MAXENT...
# 49996  NS3 PROTEIN; CATTLE; EXPRESSION; DIAGNOSIS; AN...
# 49997  NEW-SOUTH-WALES; KOALAS; INFORMATION; OPENSTRE...
# 49998  LIFE-HISTORY; MATERNAL CHARACTERISTICS; DOMINA...
# 49999  SEXUAL REPRODUCTION; ASEXUAL REPRODUCTION; CHO...
#
#                                                 Abstract  \
# 0      The incidence of emerging infectious diseases ...
# 1      Plastic is an increasingly pervasive marine po...
# 2      Human-wildlife conflict has been receiving inc...
# 3      The Arctic is changing rapidly due to climate ...
# 4      Despite the increasing frequency and magnitude...
# ...                                                  ...
# 49995  The aim of this study was to conduct an ecolog...
# 49996  Diagnosis of bovine viral diarrhea (BVD) relie...
# 49997  Geographic citizen science has much potential ...
# 49998  To better understand the potential costs and b...
# 49999  Determining demosponge reproductive strategies...
#
#                                                Addresses  Affiliations  \
# 0      [Glidden, Caroline K.; Field, Laurel C.; Bachh...           NaN
# 1      [Avery-Gomm, Stephanie] Univ Queensland, Sch B...           NaN
# 2      [Guerra, Ana Sofia] Univ Calif Santa Barbara, ...           NaN
# 3      [Halliday, William D.] Wildlife Conservat Soc ...           NaN
# 4      [Samhouri, Jameal F.; Feist, Blake E.; Fisher,...           NaN
# ...                                                  ...           ...
# 49995  [Wang, Rulin; Jiang, Chunxian; Huang, Tingting...           NaN
# 49996  [Shapouri, Masoud Reza Seyfi Abad; Choghakabod...           NaN
# 49997  [Brown, Greg] Calif Polytech State Univ San Lu...           NaN
# 49998  [Castro, Karina Charest; Leblond, Mathieu; Cot...           NaN
# 49999  [Idan, Tal; Goren, Liron; Shefer, Sigal; Brick...           NaN
#
#                                        Reprint Addresses  ...  \
# 0      Gravem, SA (corresponding author), Oregon Stat...  ...
# 1      Avery-Gomm, S (corresponding author), Univ Que...  ...
# 2      Guerra, AS (corresponding author), Univ Calif ...  ...
# 3      Halliday, WD (corresponding author), Wildlife ...  ...
# 4      Samhouri, JF (corresponding author), NOAA, Con...  ...
# ...                                                  ...  ...
# 49995  Li, Q (corresponding author), Sichuan Agr Univ...  ...
# 49996  Shapouri, MRSA (corresponding author), Shahid ...  ...
# 49997  Brown, G (corresponding author), Calif Polytec...  ...
# 49998  Leblond, M (corresponding author), Univ Laval,...  ...
# 49999  Idan, T (corresponding author), Tel Aviv Univ,...  ...
#
#       Times Cited, WoS Core Times Cited, All Databases            Publisher  \
# 0                         1                          1                WILEY
# 1                        26                         26  ELSEVIER SCIENCE BV
# 2                        28                         29     ELSEVIER SCI LTD
# 3                         1                          1     ELSEVIER SCI LTD
# 4                         4                          4            ROYAL SOC
# ...                     ...                        ...                  ...
# 49995                     5                          5                 HARD
# 49996                     0                          0           URMIA UNIV
# 49997                     9                          9                WILEY
# 49998                     1                          1                BRILL
# 49999                     3                          3   FRONTIERS MEDIA SA
#
#             ISSN      eISSN  Publication Year  \
# 0      1051-0761  1939-5582            2022.0
# 1      0048-9697  1879-1026            2018.0
# 2      0308-597X  1872-9460            2019.0
# 3      1462-9011  1873-6416            2022.0
# 4      0962-8452  1471-2954            2021.0
# ...          ...        ...               ...
# 49995        NaN        NaN            2020.0
# 49996        NaN        NaN            2022.0
# 49997        NaN        NaN               NaN
# 49998        NaN        NaN            2018.0
# 49999        NaN        NaN            2020.0
#
#                                    DOI  \
# 0                     10.1002/eap.2643
# 1      10.1016/j.scitotenv.2018.04.409
# 2         10.1016/j.marpol.2018.11.002
# 3         10.1016/j.envsci.2021.10.026
# 4               10.1098/rspb.2021.1607
# ...                                ...
# 49995            10.15244/pjoes/109306
# 49996    10.30466/vrf.2021.521500.3135
# 49997               10.1111/tgis.12568
# 49998        10.1163/1568539X-00003490
# 49999        10.3389/fmars.2020.610565
#
#                                                 DOI Link  \
# 0                     http://dx.doi.org/10.1002/eap.2643
# 1      http://dx.doi.org/10.1016/j.scitotenv.2018.04.409
# 2         http://dx.doi.org/10.1016/j.marpol.2018.11.002
# 3         http://dx.doi.org/10.1016/j.envsci.2021.10.026
# 4               http://dx.doi.org/10.1098/rspb.2021.1607
# ...                                                  ...
# 49995            http://dx.doi.org/10.15244/pjoes/109306
# 49996    http://dx.doi.org/10.30466/vrf.2021.521500.3135
# 49997               http://dx.doi.org/10.1111/tgis.12568
# 49998        http://dx.doi.org/10.1163/1568539X-00003490
# 49999        http://dx.doi.org/10.3389/fmars.2020.610565
#
#       Open Access Designations  Highly Cited Status
# 0      Green Submitted, hybrid                  NaN
# 1              Green Submitted                  NaN
# 2                          NaN                  NaN
# 3      Green Published, hybrid                  NaN
# 4      Green Published, hybrid                  NaN
# ...                        ...                  ...
# 49995                     gold                  NaN
# 49996                      NaN                  NaN
# 49997                      NaN                  NaN
# 49998                      NaN                  NaN
# 49999                     gold                  NaN
#
# [50000 rows x 24 columns]

# %%
#This will make a new column in the dataframe with the first author's country
df['First_A_Country']=first_author_country

# %%
df
# Out:
#                                                  Authors  \
# 0      Glidden, CK; Field, LC; Bachhuber, S; Hennesse...
# 1            Avery-Gomm, S; Borrelle, SB; Provencher, JF
# 2                                             Guerra, AS
# 3      Halliday, WD; Dawson, J; Yurkowski, DJ; Doniol...
# 4      Samhouri, JF; Feist, BE; Fisher, MC; Liu, O; W...
# ...                                                  ...
# 49995  Wang, RL; Jiang, CX; Huang, TT; Zhang, Z; Wang...
# 49996  Shapouri, MRSA; Mahmoodi, P; Najafabadi, MG; H...
# 49997  Brown, G; Rhodes, J; Lunney, D; Goldingay, R; ...
# 49998                   Castro, KC; Leblond, M; Cote, SD
# 49999  Idan, T; Goren, L; Shefer, S; Brickner, I; Ila...
#
#                                        Author Full Names  \
# 0      Glidden, Caroline K.; Field, Laurel C.; Bachhu...
# 1      Avery-Gomm, Stephanie; Borrelle, Stephanie B.;...
# 2                                      Guerra, Ana Sofia
# 3      Halliday, William D.; Dawson, Jackie; Yurkowsk...
# 4      Samhouri, Jameal F.; Feist, Blake E.; Fisher, ...
# ...                                                  ...
# 49995  Wang, Rulin; Jiang, Chunxian; Huang, Tingting;...
# 49996  Shapouri, Masoud Reza Seyfi Abad; Mahmoodi, Pe...
# 49997  Brown, Greg; Rhodes, Jonathan; Lunney, Daniel;...
# 49998  Castro, Karina Charest; Leblond, Mathieu; Cote...
# 49999  Idan, Tal; Goren, Liron; Shefer, Sigal; Brickn...
#
#                                            Article Title  \
# 0                 Strategies for managing marine disease
# 1      Linking plastic ingestion research with marine...
# 2      Wolves of the Sea: Managing human-wildlife con...
# 3      Vessel risks to marine wildlife in the Talluru...
# 4      Marine heatwave challenges solutions to human-...
# ...                                                  ...
# 49995  A Simulation Study of the Geographical Distrib...
# 49996  A novel competitive ELISA for detection of ant...
# 49997  The influence of sampling design on spatial da...
# 49998  Costs and benefits of post-weaning association...
# 49999  Does Depth Matter? Reproduction Pattern Plasti...
#
#                                             Source Title  \
# 0                                ECOLOGICAL APPLICATIONS
# 1                       SCIENCE OF THE TOTAL ENVIRONMENT
# 2                                          MARINE POLICY
# 3                         ENVIRONMENTAL SCIENCE & POLICY
# 4      PROCEEDINGS OF THE ROYAL SOCIETY B-BIOLOGICAL ...
# ...                                                  ...
# 49995            POLISH JOURNAL OF ENVIRONMENTAL STUDIES
# 49996                          VETERINARY RESEARCH FORUM
# 49997                                TRANSACTIONS IN GIS
# 49998                                          BEHAVIOUR
# 49999                        FRONTIERS IN MARINE SCIENCE
#
#                                          Author Keywords  \
# 0      disease ecology; marine conservation; marine w...
# 1      Plastic pollution; Conservation; Policy; Waste...
# 2      Competition; Depredation; Human-wildlife confl...
# 3      Arctic; Climate change; Marine mammals; Seabir...
# 4      trade-offs; dynamic ocean management; Dungenes...
# ...                                                  ...
# 49995  Actinidia arguta; MaxEnt; environmental factor...
# 49996  Bovine viral diarrhea; Competitive ELISA; Nons...
# 49997                                                NaN
# 49998  energy allocation trade-off; kinship interacti...
# 49999  Chondrosia reniformis; Axinella polypoides; oo...
#
#                                            Keywords Plus  \
# 0      ACUTE RESPIRATORY SYNDROME; ENDANGERED WHITE A...
# 1      DEBRIS; MANAGEMENT; SEABIRDS; MICROPLASTICS; S...
# 2      CONSERVATION; MARINE; DEPREDATION; FISHERIES; ...
# 3      CLIMATE-CHANGE; BEAUFORT SEA; SEABIRDS; SHIPS;...
# 4      ECOSYSTEM SERVICES; DYNAMIC OCEAN; WEST-COAST;...
# ...                                                  ...
# 49995  CLIMATE-CHANGE; POTENTIAL DISTRIBUTION; MAXENT...
# 49996  NS3 PROTEIN; CATTLE; EXPRESSION; DIAGNOSIS; AN...
# 49997  NEW-SOUTH-WALES; KOALAS; INFORMATION; OPENSTRE...
# 49998  LIFE-HISTORY; MATERNAL CHARACTERISTICS; DOMINA...
# 49999  SEXUAL REPRODUCTION; ASEXUAL REPRODUCTION; CHO...
#
#                                                 Abstract  \
# 0      The incidence of emerging infectious diseases ...
# 1      Plastic is an increasingly pervasive marine po...
# 2      Human-wildlife conflict has been receiving inc...
# 3      The Arctic is changing rapidly due to climate ...
# 4      Despite the increasing frequency and magnitude...
# ...                                                  ...
# 49995  The aim of this study was to conduct an ecolog...
# 49996  Diagnosis of bovine viral diarrhea (BVD) relie...
# 49997  Geographic citizen science has much potential ...
# 49998  To better understand the potential costs and b...
# 49999  Determining demosponge reproductive strategies...
#
#                                                Addresses  Affiliations  \
# 0      [Glidden, Caroline K.; Field, Laurel C.; Bachh...           NaN
# 1      [Avery-Gomm, Stephanie] Univ Queensland, Sch B...           NaN
# 2      [Guerra, Ana Sofia] Univ Calif Santa Barbara, ...           NaN
# 3      [Halliday, William D.] Wildlife Conservat Soc ...           NaN
# 4      [Samhouri, Jameal F.; Feist, Blake E.; Fisher,...           NaN
# ...                                                  ...           ...
# 49995  [Wang, Rulin; Jiang, Chunxian; Huang, Tingting...           NaN
# 49996  [Shapouri, Masoud Reza Seyfi Abad; Choghakabod...           NaN
# 49997  [Brown, Greg] Calif Polytech State Univ San Lu...           NaN
# 49998  [Castro, Karina Charest; Leblond, Mathieu; Cot...           NaN
# 49999  [Idan, Tal; Goren, Liron; Shefer, Sigal; Brick...           NaN
#
#                                        Reprint Addresses  ...  \
# 0      Gravem, SA (corresponding author), Oregon Stat...  ...
# 1      Avery-Gomm, S (corresponding author), Univ Que...  ...
# 2      Guerra, AS (corresponding author), Univ Calif ...  ...
# 3      Halliday, WD (corresponding author), Wildlife ...  ...
# 4      Samhouri, JF (corresponding author), NOAA, Con...  ...
# ...                                                  ...  ...
# 49995  Li, Q (corresponding author), Sichuan Agr Univ...  ...
# 49996  Shapouri, MRSA (corresponding author), Shahid ...  ...
# 49997  Brown, G (corresponding author), Calif Polytec...  ...
# 49998  Leblond, M (corresponding author), Univ Laval,...  ...
# 49999  Idan, T (corresponding author), Tel Aviv Univ,...  ...
#
#       Times Cited, All Databases            Publisher       ISSN      eISSN  \
# 0                              1                WILEY  1051-0761  1939-5582
# 1                             26  ELSEVIER SCIENCE BV  0048-9697  1879-1026
# 2                             29     ELSEVIER SCI LTD  0308-597X  1872-9460
# 3                              1     ELSEVIER SCI LTD  1462-9011  1873-6416
# 4                              4            ROYAL SOC  0962-8452  1471-2954
# ...                          ...                  ...        ...        ...
# 49995                          5                 HARD        NaN        NaN
# 49996                          0           URMIA UNIV        NaN        NaN
# 49997                          9                WILEY        NaN        NaN
# 49998                          1                BRILL        NaN        NaN
# 49999                          3   FRONTIERS MEDIA SA        NaN        NaN
#
#        Publication Year                              DOI  \
# 0                2022.0                 10.1002/eap.2643
# 1                2018.0  10.1016/j.scitotenv.2018.04.409
# 2                2019.0     10.1016/j.marpol.2018.11.002
# 3                2022.0     10.1016/j.envsci.2021.10.026
# 4                2021.0           10.1098/rspb.2021.1607
# ...                 ...                              ...
# 49995            2020.0            10.15244/pjoes/109306
# 49996            2022.0    10.30466/vrf.2021.521500.3135
# 49997               NaN               10.1111/tgis.12568
# 49998            2018.0        10.1163/1568539X-00003490
# 49999            2020.0        10.3389/fmars.2020.610565
#
#                                                 DOI Link  \
# 0                     http://dx.doi.org/10.1002/eap.2643
# 1      http://dx.doi.org/10.1016/j.scitotenv.2018.04.409
# 2         http://dx.doi.org/10.1016/j.marpol.2018.11.002
# 3         http://dx.doi.org/10.1016/j.envsci.2021.10.026
# 4               http://dx.doi.org/10.1098/rspb.2021.1607
# ...                                                  ...
# 49995            http://dx.doi.org/10.15244/pjoes/109306
# 49996    http://dx.doi.org/10.30466/vrf.2021.521500.3135
# 49997               http://dx.doi.org/10.1111/tgis.12568
# 49998        http://dx.doi.org/10.1163/1568539X-00003490
# 49999        http://dx.doi.org/10.3389/fmars.2020.610565
#
#       Open Access Designations Highly Cited Status  First_A_Country
# 0      Green Submitted, hybrid                 NaN              USA
# 1              Green Submitted                 NaN        Australia
# 2                          NaN                 NaN              USA
# 3      Green Published, hybrid                 NaN           Canada
# 4      Green Published, hybrid                 NaN              USA
# ...                        ...                 ...              ...
# 49995                     gold                 NaN  Peoples R China
# 49996                      NaN                 NaN             Iran
# 49997                      NaN                 NaN              USA
# 49998                      NaN                 NaN           Canada
# 49999                     gold                 NaN           Israel
#
# [50000 rows x 25 columns]

# %%
df.to_csv('Combined_WoS_Dataset.csv')

# %% [markdown]
# ## All geographic data has been transferred, and is ready to be divided for sampling
